# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\chris\Downloads\IS Core Admission Survey for IS 415 (2).csv")

df.head()
# Out:
#   Gender  \
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#
#   How did you hear about the Information Systems program?  (Select all that apply)  \
# 0             A student in the program,Family member
# 1                      IS Information Session,IS 110
# 2                      IS Information Session,IS 201
# 3                    A student in the program,IS 201
# 4  A student in the program,Family member,Informa...
#
#   Did you attend any of the following (select all that apply):  \
# 0  IS Academy,IS Cookies and Milk Information Ses...
# 1            IS Cookies and Milk Information Session
# 2  IS Academy,AIS Events (Opening Social, Closing...
# 3  BYU Major Fair,IS Academy,IS Cookies and Milk ...
# 4  Marriott Night,IS Academy,AIS Events (Opening ...
#
#   While pursuing the IS program, did you visit with any of the following (select all that apply):  \
# 0                                      IS Professors
# 1                                                NaN
# ...

# %%
from scipy import stats

f, p = stats.f_oneway(df["IS 110"],df["IS 201"], df["IS 303"])

f = round(f,2)
p = round(p,1)
print('\nF:'+str(f))
print('p:'+str(p))
# Out:
# F:341.28
# p:0.0

# %%
# Out:
# 0      3
# 1      3
# 2      0
# 3      2
# 4      2
#       ..
# 240    2
# 241    3
# 242    3
# 243    3
# 244    3
# Name: IS 303, Length: 245, dtype: int64
