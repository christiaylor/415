# %% [markdown]
# # **Data Wrangling**

# %% [markdown]
# Learning Outcomes:
#
# Prep for LO 1: Students will be able to select, run, and interpret univariate and bivariate statistical analyses and visualizations.

# %%
import pandas as pd

df = pd.read_csv('https://www.dropbox.com/s/26k4rpaezd7n4a8/insurance-pre-cleaned.csv?dl=1')

df

# %% [markdown]
# #  **Discover Missing Data**

# %% [markdown]
# What columns have missing data? How many records?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1283 non-null   float64
#  3   children  1288 non-null   float64
#  4   smoker    1327 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1335 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# bmi         55
# children    50
# smoker      11
# region       0
# charges      3
# dtype: int64

# %%
df[df['smoker'].isna()]
# Out:
#     age  gender     bmi  children smoker     region      charges
# 1    18    male  33.770       1.0    NaN  southeast   1725.55230
# 11   62  female  26.290       0.0    NaN  southeast  27808.72510
# 51   21  female  33.630       2.0    NaN  northwest   3579.82870
# 52   48    male  28.000       1.0    NaN  southwest  23568.27200
# 53   36    male  34.430       0.0    NaN  southeast  37742.57570
# 54   40  female  28.690       3.0    NaN  northwest   8059.67910
# 55   58    male  36.955       2.0    NaN  northwest  47496.49445
# 56   58  female  31.825       2.0    NaN  northeast  13607.36875
# 57   18    male  31.680       2.0    NaN  southeast  34303.16720
# 58   53  female  22.880       1.0    NaN  southeast  23244.79020
# 59   34  female  37.335       2.0    NaN  northwest   5989.52365

# %% [markdown]
# # **Deleting Columns with Missing Data**

# %% [markdown]
# You typically only delete columns in extreme cases. This is typically done when there are many null values in the column.

# %% [markdown]
# Drop all columns that have null values (used in very extreme cases)

# %%
df.dropna(axis = 1, inplace = True)
df
# Out:
#       age  gender     region
# 0      19  female  southwest
# 1      18    male  southeast
# 2      28    male  southeast
# 3      33    male  northwest
# 4      32    male  northwest
# ...   ...     ...        ...
# 1333   50    male  northwest
# 1334   18  female  northeast
# 1335   18  female  southeast
# 1336   21  female  southwest
# 1337   61  female  northwest
#
# [1338 rows x 3 columns]

# %% [markdown]
# Delete just the children column.

# %%
df = pd.read_csv('https://www.dropbox.com/s/26k4rpaezd7n4a8/insurance-pre-cleaned.csv?dl=1')

df = df.drop('children', axis =1)

df.head()
# Out:
#    age  gender     bmi smoker     region     charges
# 0   19  female  27.900    yes  southwest  16884.9240
# 1   18    male  33.770    NaN  southeast   1725.5523
# 2   28    male  33.000     no  southeast   4449.4620
# 3   33    male  22.705     no  northwest         NaN
# 4   32    male  28.880     no  northwest   3866.8552

# %% [markdown]
# # **Deleting Row with Missing Data**

# %% [markdown]
# Delete the rows that have a missing value for charges

# %%
df = pd.read_csv('https://www.dropbox.com/s/26k4rpaezd7n4a8/insurance-pre-cleaned.csv?dl=1')

df = df.dropna(subset=['charges'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1335 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1335 non-null   int64
#  1   gender    1335 non-null   object
#  2   bmi       1280 non-null   float64
#  3   children  1285 non-null   float64
#  4   smoker    1324 non-null   object
#  5   region    1335 non-null   object
#  6   charges   1335 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 83.4+ KB

# %% [markdown]
# # **Fill the Missing Values - Set Value (Imputation)**

# %% [markdown]
# If there is a set default number, you can set missing values to that.
#
# Otherwise, set numeric values to the mean or median. Set categorical values to the mode.

# %% [markdown]
# Set missing children to 0.

# %%
df['children'] = df.children.fillna(0)

df.head()
# Out:
#    age  gender    bmi  children smoker     region     charges
# 0   19  female  27.90       0.0    yes  southwest  16884.9240
# 1   18    male  33.77       1.0    NaN  southeast   1725.5523
# 2   28    male  33.00       0.0     no  southeast   4449.4620
# 4   32    male  28.88       0.0     no  northwest   3866.8552
# 5   31  female  25.74       0.0     no  southeast   3756.6216

# %% [markdown]
# Set missing bmi to bmi mean

# %%
df['bmi']=df['bmi'].fillna(df['bmi'].mean())
df.head(10)
# Out:
#     age  gender        bmi  children smoker     region     charges
# 0    19  female  27.900000       0.0    yes  southwest  16884.9240
# 1    18    male  33.770000       1.0    NaN  southeast   1725.5523
# 2    28    male  33.000000       0.0     no  southeast   4449.4620
# 4    32    male  28.880000       0.0     no  northwest   3866.8552
# 5    31  female  25.740000       0.0     no  southeast   3756.6216
# 6    46  female  33.440000       1.0     no  southeast   8240.5896
# 7    37  female  30.678598       3.0     no  northwest   7281.5056
# 8    37    male  29.830000       2.0     no  northeast   6406.4107
# 10   25    male  26.220000       0.0     no  northeast   2721.3208
# 11   62  female  26.290000       0.0    NaN  southeast  27808.7251

# %% [markdown]
# # **Bin Ages - Itertupes()**

# %%
df = pd.read_csv('https://www.dropbox.com/s/puruptejplzhts5/insurance.csv?dl=1')

# %% [markdown]
# Itertuples allow you to iterate through rows in a dataframe. There are other ways of doing the example we do below. As you explore python on your own during internships and jobs, you may come across those ways. However, I want to show you the itertuples way because you will see it again next semester in the other ML course.

# %% [markdown]
# Bin the ages into a new column called 'Age_Group'. If the age is less than 20, it is labeled 'Teens'. If the age is between 20-29, it is labeled '20s'. Continue this pattern for 30s, 40s, 50s, and 60s.

# %%
for row in df.itertuples():
    print(row)
# Out:
# Pandas(Index=0, age=19, sex='female', bmi=27.9, children=0, smoker='yes', region='southwest', charges=16884.924, Age_Group='Teens')
# Pandas(Index=1, age=18, sex='male', bmi=33.77, children=1, smoker='no', region='southeast', charges=1725.5523, Age_Group='Teens')
# Pandas(Index=2, age=28, sex='male', bmi=33.0, children=3, smoker='no', region='southeast', charges=4449.462, Age_Group='20s')
# Pandas(Index=3, age=33, sex='male', bmi=22.705, children=0, smoker='no', region='northwest', charges=21984.47061, Age_Group='30s')
# Pandas(Index=4, age=32, sex='male', bmi=28.88, children=0, smoker='no', region='northwest', charges=3866.8552, Age_Group='30s')
# Pandas(Index=5, age=31, sex='female', bmi=25.74, children=0, smoker='no', region='southeast', charges=3756.6216, Age_Group='30s')
# Pandas(Index=6, age=46, sex='female', bmi=33.44, children=1, smoker='no', region='southeast', charges=8240.5896, Age_Group='40s')
# Pandas(Index=7, age=37, sex='female', bmi=27.74, children=3, smoker='no', region='northwest', charges=7281.5056, Age_Group='30s')
# Pandas(Index=8, age=37, sex='male', bmi=29.83, children=2, smoker='no', region='northeast', charges=6406.4107, Age_Group='30s')
# Pandas(Index=9, age=60, sex='female', bmi=25.84, children=0, smoker='no', region='northwest', charges=28923.13692, Age_Group='60s')
# Pandas(Index=10, age=25, sex='male', bmi=26.22, children=0, smoker='no', region='northeast', charges=2721.3208, Age_Group='20s')
# Pandas(Index=11, age=62, sex='female', bmi=26.29, children=0, smoker='yes', region='southeast', charges=27808.7251, Age_Group='60s')
# Pandas(Index=12, age=23, sex='male', bmi=34.4, children=0, smoker='no', region='southwest', charges=1826.843, Age_Group='20s')
# Pandas(Index=13, age=56, sex='female', bmi=39.82, children=0, smoker='no', region='southeast', charges=11090.7178, Age_Group='50s')
# Pandas(Index=14, age=27, sex='male', bmi=42.13, children=0, smoker='yes', region='southeast', charges=39611.7577, Age_Group='20s')
# Pandas(Index=15, age=19, sex='male', bmi=24.6, children=1, smoker='no', region='southwest', charges=1837.237, Age_Group='Teens')
# Pandas(Index=16, age=52, sex='female', bmi=30.78, children=1, smoker='no', region='northeast', charges=10797.3362, Age_Group='50s')
# Pandas(Index=17, age=23, sex='male', bmi=23.845, children=0, smoker='no', region='northeast', charges=2395.17155, Age_Group='20s')
# Pandas(Index=18, age=56, sex='male', bmi=40.3, children=0, smoker='no', region='southwest', charges=10602.385, Age_Group='50s')
# Pandas(Index=19, age=30, sex='male', bmi=35.3, children=0, smoker='yes', region='southwest', charges=36837.467, Age_Group='30s')
# Pandas(Index=20, age=60, sex='female', bmi=36.005, children=0, smoker='no', region='northeast', charges=13228.84695, Age_Group='60s')
# Pandas(Index=21, age=30, sex='female', bmi=32.4, children=1, smoker='no', region='southwest', charges=4149.736, Age_Group='30s')
# Pandas(Index=22, age=18, sex='male', bmi=34.1, children=0, smoker='no', region='southeast', charges=1137.011, Age_Group='Teens')
# Pandas(Index=23, age=34, sex='female', bmi=31.92, children=1, smoker='yes', region='northeast', charges=37701.8768, Age_Group='30s')
# Pandas(Index=24, age=37, sex='male', bmi=28.025, children=2, smoker='no', region='northwest', charges=6203.90175, Age_Group='30s')
# Pandas(Index=25, age=59, sex='female', bmi=27.72, children=3, smoker='no', region='southeast', charges=14001.1338, Age_Group='50s')
# Pandas(Index=26, age=63, sex='female', bmi=23.085, children=0, smoker='no', region='northeast', charges=14451.83515, Age_Group='60s')
# Pandas(Index=27, age=55, sex='female', bmi=32.775, children=2, smoker='no', region='northwest', charges=12268.63225, Age_Group='50s')
# Pandas(Index=28, age=23, sex='male', bmi=17.385, children=1, smoker='no', region='northwest', charges=2775.19215, Age_Group='20s')
# Pandas(Index=29, age=31, sex='male', bmi=36.3, children=2, smoker='yes', region='southwest', charges=38711.0, Age_Group='30s')
# Pandas(Index=30, age=22, sex='male', bmi=35.6, children=0, smoker='yes', region='southwest', charges=35585.576, Age_Group='20s')
# Pandas(Index=31, age=18, sex='female', bmi=26.315, children=0, smoker='no', region='northeast', charges=2198.18985, Age_Group='Teens')
# Pandas(Index=32, age=19, sex='female', bmi=28.6, children=5, smoker='no', region='southwest', charges=4687.797, Age_Group='Teens')
# Pandas(Index=33, age=63, sex='male', bmi=28.31, children=0, smoker='no', region='northwest', charges=13770.0979, Age_Group='60s')
# Pandas(Index=34, age=28, sex='male', bmi=36.4, children=1, smoker='yes', region='southwest', charges=51194.55914, Age_Group='20s')
# Pandas(Index=35, age=19, sex='male', bmi=20.425, children=0, smoker='no', region='northwest', charges=1625.43375, Age_Group='Teens')
# Pandas(Index=36, age=62, sex='female', bmi=32.965, children=3, smoker='no', region='northwest', charges=15612.19335, Age_Group='60s')
# Pandas(Index=37, age=26, sex='male', bmi=20.8, children=0, smoker='no', region='southwest', charges=2302.3, Age_Group='20s')
# Pandas(Index=38, age=35, sex='male', bmi=36.67, children=1, smoker='yes', region='northeast', charges=39774.2763, Age_Group='30s')
# Pandas(Index=39, age=60, sex='male', bmi=39.9, children=0, smoker='yes', region='southwest', charges=48173.361, Age_Group='60s')
# Pandas(Index=40, age=24, sex='female', bmi=26.6, children=0, smoker='no', region='northeast', charges=3046.062, Age_Group='20s')
# Pandas(Index=41, age=31, sex='female', bmi=36.63, children=2, smoker='no', region='southeast', charges=4949.7587, Age_Group='30s')
# Pandas(Index=42, age=41, sex='male', bmi=21.78, children=1, smoker='no', region='southeast', charges=6272.4772, Age_Group='40s')
# Pandas(Index=43, age=37, sex='female', bmi=30.8, children=2, smoker='no', region='southeast', charges=6313.759, Age_Group='30s')
# Pandas(Index=44, age=38, sex='male', bmi=37.05, children=1, smoker='no', region='northeast', charges=6079.6715, Age_Group='30s')
# Pandas(Index=45, age=55, sex='male', bmi=37.3, children=0, smoker='no', region='southwest', charges=20630.28351, Age_Group='50s')
# Pandas(Index=46, age=18, sex='female', bmi=38.665, children=2, smoker='no', region='northeast', charges=3393.35635, Age_Group='Teens')
# Pandas(Index=47, age=28, sex='female', bmi=34.77, children=0, smoker='no', region='northwest', charges=3556.9223, Age_Group='20s')
# Pandas(Index=48, age=60, sex='female', bmi=24.53, children=0, smoker='no', region='southeast', charges=12629.8967, Age_Group='60s')
# Pandas(Index=49, age=36, sex='male', bmi=35.2, children=1, smoker='yes', region='southeast', charges=38709.176, Age_Group='30s')
# Pandas(Index=50, age=18, sex='female', bmi=35.625, children=0, smoker='no', region='northeast', charges=2211.13075, Age_Group='Teens')
# Pandas(Index=51, age=21, sex='female', bmi=33.63, children=2, smoker='no', region='northwest', charges=3579.8287, Age_Group='20s')
# Pandas(Index=52, age=48, sex='male', bmi=28.0, children=1, smoker='yes', region='southwest', charges=23568.272, Age_Group='40s')
# Pandas(Index=53, age=36, sex='male', bmi=34.43, children=0, smoker='yes', region='southeast', charges=37742.5757, Age_Group='30s')
# Pandas(Index=54, age=40, sex='female', bmi=28.69, children=3, smoker='no', region='northwest', charges=8059.6791, Age_Group='40s')
# Pandas(Index=55, age=58, sex='male', bmi=36.955, children=2, smoker='yes', region='northwest', charges=47496.49445, Age_Group='50s')
# Pandas(Index=56, age=58, sex='female', bmi=31.825, children=2, smoker='no', region='northeast', charges=13607.36875, Age_Group='50s')
# Pandas(Index=57, age=18, sex='male', bmi=31.68, children=2, smoker='yes', region='southeast', charges=34303.1672, Age_Group='Teens')
# Pandas(Index=58, age=53, sex='female', bmi=22.88, children=1, smoker='yes', region='southeast', charges=23244.7902, Age_Group='50s')
# Pandas(Index=59, age=34, sex='female', bmi=37.335, children=2, smoker='no', region='northwest', charges=5989.52365, Age_Group='30s')
# Pandas(Index=60, age=43, sex='male', bmi=27.36, children=3, smoker='no', region='northeast', charges=8606.2174, Age_Group='40s')
# Pandas(Index=61, age=25, sex='male', bmi=33.66, children=4, smoker='no', region='southeast', charges=4504.6624, Age_Group='20s')
# Pandas(Index=62, age=64, sex='male', bmi=24.7, children=1, smoker='no', region='northwest', charges=30166.61817, Age_Group='60s')
# Pandas(Index=63, age=28, sex='female', bmi=25.935, children=1, smoker='no', region='northwest', charges=4133.64165, Age_Group='20s')
# Pandas(Index=64, age=20, sex='female', bmi=22.42, children=0, smoker='yes', region='northwest', charges=14711.7438, Age_Group='20s')
# Pandas(Index=65, age=19, sex='female', bmi=28.9, children=0, smoker='no', region='southwest', charges=1743.214, Age_Group='Teens')
# Pandas(Index=66, age=61, sex='female', bmi=39.1, children=2, smoker='no', region='southwest', charges=14235.072, Age_Group='60s')
# Pandas(Index=67, age=40, sex='male', bmi=26.315, children=1, smoker='no', region='northwest', charges=6389.37785, Age_Group='40s')
# Pandas(Index=68, age=40, sex='female', bmi=36.19, children=0, smoker='no', region='southeast', charges=5920.1041, Age_Group='40s')
# Pandas(Index=69, age=28, sex='male', bmi=23.98, children=3, smoker='yes', region='southeast', charges=17663.1442, Age_Group='20s')
# Pandas(Index=70, age=27, sex='female', bmi=24.75, children=0, smoker='yes', region='southeast', charges=16577.7795, Age_Group='20s')
# Pandas(Index=71, age=31, sex='male', bmi=28.5, children=5, smoker='no', region='northeast', charges=6799.458, Age_Group='30s')
# Pandas(Index=72, age=53, sex='female', bmi=28.1, children=3, smoker='no', region='southwest', charges=11741.726, Age_Group='50s')
# Pandas(Index=73, age=58, sex='male', bmi=32.01, children=1, smoker='no', region='southeast', charges=11946.6259, Age_Group='50s')
# Pandas(Index=74, age=44, sex='male', bmi=27.4, children=2, smoker='no', region='southwest', charges=7726.854, Age_Group='40s')
# Pandas(Index=75, age=57, sex='male', bmi=34.01, children=0, smoker='no', region='northwest', charges=11356.6609, Age_Group='50s')
# Pandas(Index=76, age=29, sex='female', bmi=29.59, children=1, smoker='no', region='southeast', charges=3947.4131, Age_Group='20s')
# Pandas(Index=77, age=21, sex='male', bmi=35.53, children=0, smoker='no', region='southeast', charges=1532.4697, Age_Group='20s')
# Pandas(Index=78, age=22, sex='female', bmi=39.805, children=0, smoker='no', region='northeast', charges=2755.02095, Age_Group='20s')
# Pandas(Index=79, age=41, sex='female', bmi=32.965, children=0, smoker='no', region='northwest', charges=6571.02435, Age_Group='40s')
# Pandas(Index=80, age=31, sex='male', bmi=26.885, children=1, smoker='no', region='northeast', charges=4441.21315, Age_Group='30s')
# Pandas(Index=81, age=45, sex='female', bmi=38.285, children=0, smoker='no', region='northeast', charges=7935.29115, Age_Group='40s')
# Pandas(Index=82, age=22, sex='male', bmi=37.62, children=1, smoker='yes', region='southeast', charges=37165.1638, Age_Group='20s')
# Pandas(Index=83, age=48, sex='female', bmi=41.23, children=4, smoker='no', region='northwest', charges=11033.6617, Age_Group='40s')
# Pandas(Index=84, age=37, sex='female', bmi=34.8, children=2, smoker='yes', region='southwest', charges=39836.519, Age_Group='30s')
# Pandas(Index=85, age=45, sex='male', bmi=22.895, children=2, smoker='yes', region='northwest', charges=21098.55405, Age_Group='40s')
# Pandas(Index=86, age=57, sex='female', bmi=31.16, children=0, smoker='yes', region='northwest', charges=43578.9394, Age_Group='50s')
# Pandas(Index=87, age=56, sex='female', bmi=27.2, children=0, smoker='no', region='southwest', charges=11073.176, Age_Group='50s')
# Pandas(Index=88, age=46, sex='female', bmi=27.74, children=0, smoker='no', region='northwest', charges=8026.6666, Age_Group='40s')
# Pandas(Index=89, age=55, sex='female', bmi=26.98, children=0, smoker='no', region='northwest', charges=11082.5772, Age_Group='50s')
# Pandas(Index=90, age=21, sex='female', bmi=39.49, children=0, smoker='no', region='southeast', charges=2026.9741, Age_Group='20s')
# Pandas(Index=91, age=53, sex='female', bmi=24.795, children=1, smoker='no', region='northwest', charges=10942.13205, Age_Group='50s')
# Pandas(Index=92, age=59, sex='male', bmi=29.83, children=3, smoker='yes', region='northeast', charges=30184.9367, Age_Group='50s')
# Pandas(Index=93, age=35, sex='male', bmi=34.77, children=2, smoker='no', region='northwest', charges=5729.0053, Age_Group='30s')
# Pandas(Index=94, age=64, sex='female', bmi=31.3, children=2, smoker='yes', region='southwest', charges=47291.055, Age_Group='60s')
# Pandas(Index=95, age=28, sex='female', bmi=37.62, children=1, smoker='no', region='southeast', charges=3766.8838, Age_Group='20s')
# Pandas(Index=96, age=54, sex='female', bmi=30.8, children=3, smoker='no', region='southwest', charges=12105.32, Age_Group='50s')
# Pandas(Index=97, age=55, sex='male', bmi=38.28, children=0, smoker='no', region='southeast', charges=10226.2842, Age_Group='50s')
# Pandas(Index=98, age=56, sex='male', bmi=19.95, children=0, smoker='yes', region='northeast', charges=22412.6485, Age_Group='50s')
# Pandas(Index=99, age=38, sex='male', bmi=19.3, children=0, smoker='yes', region='southwest', charges=15820.699, Age_Group='30s')
# Pandas(Index=100, age=41, sex='female', bmi=31.6, children=0, smoker='no', region='southwest', charges=6186.127, Age_Group='40s')
# Pandas(Index=101, age=30, sex='male', bmi=25.46, children=0, smoker='no', region='northeast', charges=3645.0894, Age_Group='30s')
# Pandas(Index=102, age=18, sex='female', bmi=30.115, children=0, smoker='no', region='northeast', charges=21344.8467, Age_Group='Teens')
# Pandas(Index=103, age=61, sex='female', bmi=29.92, children=3, smoker='yes', region='southeast', charges=30942.1918, Age_Group='60s')
# Pandas(Index=104, age=34, sex='female', bmi=27.5, children=1, smoker='no', region='southwest', charges=5003.853, Age_Group='30s')
# Pandas(Index=105, age=20, sex='male', bmi=28.025, children=1, smoker='yes', region='northwest', charges=17560.37975, Age_Group='20s')
# Pandas(Index=106, age=19, sex='female', bmi=28.4, children=1, smoker='no', region='southwest', charges=2331.519, Age_Group='Teens')
# Pandas(Index=107, age=26, sex='male', bmi=30.875, children=2, smoker='no', region='northwest', charges=3877.30425, Age_Group='20s')
# Pandas(Index=108, age=29, sex='male', bmi=27.94, children=0, smoker='no', region='southeast', charges=2867.1196, Age_Group='20s')
# Pandas(Index=109, age=63, sex='male', bmi=35.09, children=0, smoker='yes', region='southeast', charges=47055.5321, Age_Group='60s')
# Pandas(Index=110, age=54, sex='male', bmi=33.63, children=1, smoker='no', region='northwest', charges=10825.2537, Age_Group='50s')
# Pandas(Index=111, age=55, sex='female', bmi=29.7, children=2, smoker='no', region='southwest', charges=11881.358, Age_Group='50s')
# Pandas(Index=112, age=37, sex='male', bmi=30.8, children=0, smoker='no', region='southwest', charges=4646.759, Age_Group='30s')
# Pandas(Index=113, age=21, sex='female', bmi=35.72, children=0, smoker='no', region='northwest', charges=2404.7338, Age_Group='20s')
# Pandas(Index=114, age=52, sex='male', bmi=32.205, children=3, smoker='no', region='northeast', charges=11488.31695, Age_Group='50s')
# Pandas(Index=115, age=60, sex='male', bmi=28.595, children=0, smoker='no', region='northeast', charges=30259.99556, Age_Group='60s')
# Pandas(Index=116, age=58, sex='male', bmi=49.06, children=0, smoker='no', region='southeast', charges=11381.3254, Age_Group='50s')
# Pandas(Index=117, age=29, sex='female', bmi=27.94, children=1, smoker='yes', region='southeast', charges=19107.7796, Age_Group='20s')
# Pandas(Index=118, age=49, sex='female', bmi=27.17, children=0, smoker='no', region='southeast', charges=8601.3293, Age_Group='40s')
# Pandas(Index=119, age=37, sex='female', bmi=23.37, children=2, smoker='no', region='northwest', charges=6686.4313, Age_Group='30s')
# Pandas(Index=120, age=44, sex='male', bmi=37.1, children=2, smoker='no', region='southwest', charges=7740.337, Age_Group='40s')
# Pandas(Index=121, age=18, sex='male', bmi=23.75, children=0, smoker='no', region='northeast', charges=1705.6245, Age_Group='Teens')
# Pandas(Index=122, age=20, sex='female', bmi=28.975, children=0, smoker='no', region='northwest', charges=2257.47525, Age_Group='20s')
# Pandas(Index=123, age=44, sex='male', bmi=31.35, children=1, smoker='yes', region='northeast', charges=39556.4945, Age_Group='40s')
# Pandas(Index=124, age=47, sex='female', bmi=33.915, children=3, smoker='no', region='northwest', charges=10115.00885, Age_Group='40s')
# Pandas(Index=125, age=26, sex='female', bmi=28.785, children=0, smoker='no', region='northeast', charges=3385.39915, Age_Group='20s')
# Pandas(Index=126, age=19, sex='female', bmi=28.3, children=0, smoker='yes', region='southwest', charges=17081.08, Age_Group='Teens')
# Pandas(Index=127, age=52, sex='female', bmi=37.4, children=0, smoker='no', region='southwest', charges=9634.538, Age_Group='50s')
# Pandas(Index=128, age=32, sex='female', bmi=17.765, children=2, smoker='yes', region='northwest', charges=32734.1863, Age_Group='30s')
# Pandas(Index=129, age=38, sex='male', bmi=34.7, children=2, smoker='no', region='southwest', charges=6082.405, Age_Group='30s')
# Pandas(Index=130, age=59, sex='female', bmi=26.505, children=0, smoker='no', region='northeast', charges=12815.44495, Age_Group='50s')
# Pandas(Index=131, age=61, sex='female', bmi=22.04, children=0, smoker='no', region='northeast', charges=13616.3586, Age_Group='60s')
# Pandas(Index=132, age=53, sex='female', bmi=35.9, children=2, smoker='no', region='southwest', charges=11163.568, Age_Group='50s')
# Pandas(Index=133, age=19, sex='male', bmi=25.555, children=0, smoker='no', region='northwest', charges=1632.56445, Age_Group='Teens')
# Pandas(Index=134, age=20, sex='female', bmi=28.785, children=0, smoker='no', region='northeast', charges=2457.21115, Age_Group='20s')
# Pandas(Index=135, age=22, sex='female', bmi=28.05, children=0, smoker='no', region='southeast', charges=2155.6815, Age_Group='20s')
# Pandas(Index=136, age=19, sex='male', bmi=34.1, children=0, smoker='no', region='southwest', charges=1261.442, Age_Group='Teens')
# Pandas(Index=137, age=22, sex='male', bmi=25.175, children=0, smoker='no', region='northwest', charges=2045.68525, Age_Group='20s')
# Pandas(Index=138, age=54, sex='female', bmi=31.9, children=3, smoker='no', region='southeast', charges=27322.73386, Age_Group='50s')
# Pandas(Index=139, age=22, sex='female', bmi=36.0, children=0, smoker='no', region='southwest', charges=2166.732, Age_Group='20s')
# Pandas(Index=140, age=34, sex='male', bmi=22.42, children=2, smoker='no', region='northeast', charges=27375.90478, Age_Group='30s')
# Pandas(Index=141, age=26, sex='male', bmi=32.49, children=1, smoker='no', region='northeast', charges=3490.5491, Age_Group='20s')
# Pandas(Index=142, age=34, sex='male', bmi=25.3, children=2, smoker='yes', region='southeast', charges=18972.495, Age_Group='30s')
# Pandas(Index=143, age=29, sex='male', bmi=29.735, children=2, smoker='no', region='northwest', charges=18157.876, Age_Group='20s')
# Pandas(Index=144, age=30, sex='male', bmi=28.69, children=3, smoker='yes', region='northwest', charges=20745.9891, Age_Group='30s')
# Pandas(Index=145, age=29, sex='female', bmi=38.83, children=3, smoker='no', region='southeast', charges=5138.2567, Age_Group='20s')
# Pandas(Index=146, age=46, sex='male', bmi=30.495, children=3, smoker='yes', region='northwest', charges=40720.55105, Age_Group='40s')
# Pandas(Index=147, age=51, sex='female', bmi=37.73, children=1, smoker='no', region='southeast', charges=9877.6077, Age_Group='50s')
# Pandas(Index=148, age=53, sex='female', bmi=37.43, children=1, smoker='no', region='northwest', charges=10959.6947, Age_Group='50s')
# Pandas(Index=149, age=19, sex='male', bmi=28.4, children=1, smoker='no', region='southwest', charges=1842.519, Age_Group='Teens')
# Pandas(Index=150, age=35, sex='male', bmi=24.13, children=1, smoker='no', region='northwest', charges=5125.2157, Age_Group='30s')
# Pandas(Index=151, age=48, sex='male', bmi=29.7, children=0, smoker='no', region='southeast', charges=7789.635, Age_Group='40s')
# Pandas(Index=152, age=32, sex='female', bmi=37.145, children=3, smoker='no', region='northeast', charges=6334.34355, Age_Group='30s')
# Pandas(Index=153, age=42, sex='female', bmi=23.37, children=0, smoker='yes', region='northeast', charges=19964.7463, Age_Group='40s')
# Pandas(Index=154, age=40, sex='female', bmi=25.46, children=1, smoker='no', region='northeast', charges=7077.1894, Age_Group='40s')
# Pandas(Index=155, age=44, sex='male', bmi=39.52, children=0, smoker='no', region='northwest', charges=6948.7008, Age_Group='40s')
# Pandas(Index=156, age=48, sex='male', bmi=24.42, children=0, smoker='yes', region='southeast', charges=21223.6758, Age_Group='40s')
# Pandas(Index=157, age=18, sex='male', bmi=25.175, children=0, smoker='yes', region='northeast', charges=15518.18025, Age_Group='Teens')
# Pandas(Index=158, age=30, sex='male', bmi=35.53, children=0, smoker='yes', region='southeast', charges=36950.2567, Age_Group='30s')
# Pandas(Index=159, age=50, sex='female', bmi=27.83, children=3, smoker='no', region='southeast', charges=19749.38338, Age_Group='50s')
# Pandas(Index=160, age=42, sex='female', bmi=26.6, children=0, smoker='yes', region='northwest', charges=21348.706, Age_Group='40s')
# Pandas(Index=161, age=18, sex='female', bmi=36.85, children=0, smoker='yes', region='southeast', charges=36149.4835, Age_Group='Teens')
# Pandas(Index=162, age=54, sex='male', bmi=39.6, children=1, smoker='no', region='southwest', charges=10450.552, Age_Group='50s')
# Pandas(Index=163, age=32, sex='female', bmi=29.8, children=2, smoker='no', region='southwest', charges=5152.134, Age_Group='30s')
# Pandas(Index=164, age=37, sex='male', bmi=29.64, children=0, smoker='no', region='northwest', charges=5028.1466, Age_Group='30s')
# Pandas(Index=165, age=47, sex='male', bmi=28.215, children=4, smoker='no', region='northeast', charges=10407.08585, Age_Group='40s')
# Pandas(Index=166, age=20, sex='female', bmi=37.0, children=5, smoker='no', region='southwest', charges=4830.63, Age_Group='20s')
# Pandas(Index=167, age=32, sex='female', bmi=33.155, children=3, smoker='no', region='northwest', charges=6128.79745, Age_Group='30s')
# Pandas(Index=168, age=19, sex='female', bmi=31.825, children=1, smoker='no', region='northwest', charges=2719.27975, Age_Group='Teens')
# Pandas(Index=169, age=27, sex='male', bmi=18.905, children=3, smoker='no', region='northeast', charges=4827.90495, Age_Group='20s')
# Pandas(Index=170, age=63, sex='male', bmi=41.47, children=0, smoker='no', region='southeast', charges=13405.3903, Age_Group='60s')
# Pandas(Index=171, age=49, sex='male', bmi=30.3, children=0, smoker='no', region='southwest', charges=8116.68, Age_Group='40s')
# Pandas(Index=172, age=18, sex='male', bmi=15.96, children=0, smoker='no', region='northeast', charges=1694.7964, Age_Group='Teens')
# Pandas(Index=173, age=35, sex='female', bmi=34.8, children=1, smoker='no', region='southwest', charges=5246.047, Age_Group='30s')
# Pandas(Index=174, age=24, sex='female', bmi=33.345, children=0, smoker='no', region='northwest', charges=2855.43755, Age_Group='20s')
# Pandas(Index=175, age=63, sex='female', bmi=37.7, children=0, smoker='yes', region='southwest', charges=48824.45, Age_Group='60s')
# Pandas(Index=176, age=38, sex='male', bmi=27.835, children=2, smoker='no', region='northwest', charges=6455.86265, Age_Group='30s')
# Pandas(Index=177, age=54, sex='male', bmi=29.2, children=1, smoker='no', region='southwest', charges=10436.096, Age_Group='50s')
# Pandas(Index=178, age=46, sex='female', bmi=28.9, children=2, smoker='no', region='southwest', charges=8823.279, Age_Group='40s')
# Pandas(Index=179, age=41, sex='female', bmi=33.155, children=3, smoker='no', region='northeast', charges=8538.28845, Age_Group='40s')
# Pandas(Index=180, age=58, sex='male', bmi=28.595, children=0, smoker='no', region='northwest', charges=11735.87905, Age_Group='50s')
# Pandas(Index=181, age=18, sex='female', bmi=38.28, children=0, smoker='no', region='southeast', charges=1631.8212, Age_Group='Teens')
# Pandas(Index=182, age=22, sex='male', bmi=19.95, children=3, smoker='no', region='northeast', charges=4005.4225, Age_Group='20s')
# Pandas(Index=183, age=44, sex='female', bmi=26.41, children=0, smoker='no', region='northwest', charges=7419.4779, Age_Group='40s')
# Pandas(Index=184, age=44, sex='male', bmi=30.69, children=2, smoker='no', region='southeast', charges=7731.4271, Age_Group='40s')
# Pandas(Index=185, age=36, sex='male', bmi=41.895, children=3, smoker='yes', region='northeast', charges=43753.33705, Age_Group='30s')
# Pandas(Index=186, age=26, sex='female', bmi=29.92, children=2, smoker='no', region='southeast', charges=3981.9768, Age_Group='20s')
# Pandas(Index=187, age=30, sex='female', bmi=30.9, children=3, smoker='no', region='southwest', charges=5325.651, Age_Group='30s')
# Pandas(Index=188, age=41, sex='female', bmi=32.2, children=1, smoker='no', region='southwest', charges=6775.961, Age_Group='40s')
# Pandas(Index=189, age=29, sex='female', bmi=32.11, children=2, smoker='no', region='northwest', charges=4922.9159, Age_Group='20s')
# Pandas(Index=190, age=61, sex='male', bmi=31.57, children=0, smoker='no', region='southeast', charges=12557.6053, Age_Group='60s')
# Pandas(Index=191, age=36, sex='female', bmi=26.2, children=0, smoker='no', region='southwest', charges=4883.866, Age_Group='30s')
# Pandas(Index=192, age=25, sex='male', bmi=25.74, children=0, smoker='no', region='southeast', charges=2137.6536, Age_Group='20s')
# Pandas(Index=193, age=56, sex='female', bmi=26.6, children=1, smoker='no', region='northwest', charges=12044.342, Age_Group='50s')
# Pandas(Index=194, age=18, sex='male', bmi=34.43, children=0, smoker='no', region='southeast', charges=1137.4697, Age_Group='Teens')
# Pandas(Index=195, age=19, sex='male', bmi=30.59, children=0, smoker='no', region='northwest', charges=1639.5631, Age_Group='Teens')
# Pandas(Index=196, age=39, sex='female', bmi=32.8, children=0, smoker='no', region='southwest', charges=5649.715, Age_Group='30s')
# Pandas(Index=197, age=45, sex='female', bmi=28.6, children=2, smoker='no', region='southeast', charges=8516.829, Age_Group='40s')
# Pandas(Index=198, age=51, sex='female', bmi=18.05, children=0, smoker='no', region='northwest', charges=9644.2525, Age_Group='50s')
# Pandas(Index=199, age=64, sex='female', bmi=39.33, children=0, smoker='no', region='northeast', charges=14901.5167, Age_Group='60s')
# Pandas(Index=200, age=19, sex='female', bmi=32.11, children=0, smoker='no', region='northwest', charges=2130.6759, Age_Group='Teens')
# Pandas(Index=201, age=48, sex='female', bmi=32.23, children=1, smoker='no', region='southeast', charges=8871.1517, Age_Group='40s')
# Pandas(Index=202, age=60, sex='female', bmi=24.035, children=0, smoker='no', region='northwest', charges=13012.20865, Age_Group='60s')
# Pandas(Index=203, age=27, sex='female', bmi=36.08, children=0, smoker='yes', region='southeast', charges=37133.8982, Age_Group='20s')
# Pandas(Index=204, age=46, sex='male', bmi=22.3, children=0, smoker='no', region='southwest', charges=7147.105, Age_Group='40s')
# Pandas(Index=205, age=28, sex='female', bmi=28.88, children=1, smoker='no', region='northeast', charges=4337.7352, Age_Group='20s')
# Pandas(Index=206, age=59, sex='male', bmi=26.4, children=0, smoker='no', region='southeast', charges=11743.299, Age_Group='50s')
# Pandas(Index=207, age=35, sex='male', bmi=27.74, children=2, smoker='yes', region='northeast', charges=20984.0936, Age_Group='30s')
# Pandas(Index=208, age=63, sex='female', bmi=31.8, children=0, smoker='no', region='southwest', charges=13880.949, Age_Group='60s')
# Pandas(Index=209, age=40, sex='male', bmi=41.23, children=1, smoker='no', region='northeast', charges=6610.1097, Age_Group='40s')
# Pandas(Index=210, age=20, sex='male', bmi=33.0, children=1, smoker='no', region='southwest', charges=1980.07, Age_Group='20s')
# Pandas(Index=211, age=40, sex='male', bmi=30.875, children=4, smoker='no', region='northwest', charges=8162.71625, Age_Group='40s')
# Pandas(Index=212, age=24, sex='male', bmi=28.5, children=2, smoker='no', region='northwest', charges=3537.703, Age_Group='20s')
# Pandas(Index=213, age=34, sex='female', bmi=26.73, children=1, smoker='no', region='southeast', charges=5002.7827, Age_Group='30s')
# Pandas(Index=214, age=45, sex='female', bmi=30.9, children=2, smoker='no', region='southwest', charges=8520.026, Age_Group='40s')
# Pandas(Index=215, age=41, sex='female', bmi=37.1, children=2, smoker='no', region='southwest', charges=7371.772, Age_Group='40s')
# Pandas(Index=216, age=53, sex='female', bmi=26.6, children=0, smoker='no', region='northwest', charges=10355.641, Age_Group='50s')
# Pandas(Index=217, age=27, sex='male', bmi=23.1, children=0, smoker='no', region='southeast', charges=2483.736, Age_Group='20s')
# Pandas(Index=218, age=26, sex='female', bmi=29.92, children=1, smoker='no', region='southeast', charges=3392.9768, Age_Group='20s')
# Pandas(Index=219, age=24, sex='female', bmi=23.21, children=0, smoker='no', region='southeast', charges=25081.76784, Age_Group='20s')
# Pandas(Index=220, age=34, sex='female', bmi=33.7, children=1, smoker='no', region='southwest', charges=5012.471, Age_Group='30s')
# Pandas(Index=221, age=53, sex='female', bmi=33.25, children=0, smoker='no', region='northeast', charges=10564.8845, Age_Group='50s')
# Pandas(Index=222, age=32, sex='male', bmi=30.8, children=3, smoker='no', region='southwest', charges=5253.524, Age_Group='30s')
# Pandas(Index=223, age=19, sex='male', bmi=34.8, children=0, smoker='yes', region='southwest', charges=34779.615, Age_Group='Teens')
# Pandas(Index=224, age=42, sex='male', bmi=24.64, children=0, smoker='yes', region='southeast', charges=19515.5416, Age_Group='40s')
# Pandas(Index=225, age=55, sex='male', bmi=33.88, children=3, smoker='no', region='southeast', charges=11987.1682, Age_Group='50s')
# Pandas(Index=226, age=28, sex='male', bmi=38.06, children=0, smoker='no', region='southeast', charges=2689.4954, Age_Group='20s')
# Pandas(Index=227, age=58, sex='female', bmi=41.91, children=0, smoker='no', region='southeast', charges=24227.33724, Age_Group='50s')
# Pandas(Index=228, age=41, sex='female', bmi=31.635, children=1, smoker='no', region='northeast', charges=7358.17565, Age_Group='40s')
# Pandas(Index=229, age=47, sex='male', bmi=25.46, children=2, smoker='no', region='northeast', charges=9225.2564, Age_Group='40s')
# Pandas(Index=230, age=42, sex='female', bmi=36.195, children=1, smoker='no', region='northwest', charges=7443.64305, Age_Group='40s')
# Pandas(Index=231, age=59, sex='female', bmi=27.83, children=3, smoker='no', region='southeast', charges=14001.2867, Age_Group='50s')
# Pandas(Index=232, age=19, sex='female', bmi=17.8, children=0, smoker='no', region='southwest', charges=1727.785, Age_Group='Teens')
# Pandas(Index=233, age=59, sex='male', bmi=27.5, children=1, smoker='no', region='southwest', charges=12333.828, Age_Group='50s')
# Pandas(Index=234, age=39, sex='male', bmi=24.51, children=2, smoker='no', region='northwest', charges=6710.1919, Age_Group='30s')
# Pandas(Index=235, age=40, sex='female', bmi=22.22, children=2, smoker='yes', region='southeast', charges=19444.2658, Age_Group='40s')
# Pandas(Index=236, age=18, sex='female', bmi=26.73, children=0, smoker='no', region='southeast', charges=1615.7667, Age_Group='Teens')
# Pandas(Index=237, age=31, sex='male', bmi=38.39, children=2, smoker='no', region='southeast', charges=4463.2051, Age_Group='30s')
# Pandas(Index=238, age=19, sex='male', bmi=29.07, children=0, smoker='yes', region='northwest', charges=17352.6803, Age_Group='Teens')
# Pandas(Index=239, age=44, sex='male', bmi=38.06, children=1, smoker='no', region='southeast', charges=7152.6714, Age_Group='40s')
# Pandas(Index=240, age=23, sex='female', bmi=36.67, children=2, smoker='yes', region='northeast', charges=38511.6283, Age_Group='20s')
# Pandas(Index=241, age=33, sex='female', bmi=22.135, children=1, smoker='no', region='northeast', charges=5354.07465, Age_Group='30s')
# Pandas(Index=242, age=55, sex='female', bmi=26.8, children=1, smoker='no', region='southwest', charges=35160.13457, Age_Group='50s')
# Pandas(Index=243, age=40, sex='male', bmi=35.3, children=3, smoker='no', region='southwest', charges=7196.867, Age_Group='40s')
# Pandas(Index=244, age=63, sex='female', bmi=27.74, children=0, smoker='yes', region='northeast', charges=29523.1656, Age_Group='60s')
# Pandas(Index=245, age=54, sex='male', bmi=30.02, children=0, smoker='no', region='northwest', charges=24476.47851, Age_Group='50s')
# Pandas(Index=246, age=60, sex='female', bmi=38.06, children=0, smoker='no', region='southeast', charges=12648.7034, Age_Group='60s')
# Pandas(Index=247, age=24, sex='male', bmi=35.86, children=0, smoker='no', region='southeast', charges=1986.9334, Age_Group='20s')
# Pandas(Index=248, age=19, sex='male', bmi=20.9, children=1, smoker='no', region='southwest', charges=1832.094, Age_Group='Teens')
# Pandas(Index=249, age=29, sex='male', bmi=28.975, children=1, smoker='no', region='northeast', charges=4040.55825, Age_Group='20s')
# Pandas(Index=250, age=18, sex='male', bmi=17.29, children=2, smoker='yes', region='northeast', charges=12829.4551, Age_Group='Teens')
# Pandas(Index=251, age=63, sex='female', bmi=32.2, children=2, smoker='yes', region='southwest', charges=47305.305, Age_Group='60s')
# Pandas(Index=252, age=54, sex='male', bmi=34.21, children=2, smoker='yes', region='southeast', charges=44260.7499, Age_Group='50s')
# Pandas(Index=253, age=27, sex='male', bmi=30.3, children=3, smoker='no', region='southwest', charges=4260.744, Age_Group='20s')
# Pandas(Index=254, age=50, sex='male', bmi=31.825, children=0, smoker='yes', region='northeast', charges=41097.16175, Age_Group='50s')
# Pandas(Index=255, age=55, sex='female', bmi=25.365, children=3, smoker='no', region='northeast', charges=13047.33235, Age_Group='50s')
# Pandas(Index=256, age=56, sex='male', bmi=33.63, children=0, smoker='yes', region='northwest', charges=43921.1837, Age_Group='50s')
# Pandas(Index=257, age=38, sex='female', bmi=40.15, children=0, smoker='no', region='southeast', charges=5400.9805, Age_Group='30s')
# Pandas(Index=258, age=51, sex='male', bmi=24.415, children=4, smoker='no', region='northwest', charges=11520.09985, Age_Group='50s')
# Pandas(Index=259, age=19, sex='male', bmi=31.92, children=0, smoker='yes', region='northwest', charges=33750.2918, Age_Group='Teens')
# Pandas(Index=260, age=58, sex='female', bmi=25.2, children=0, smoker='no', region='southwest', charges=11837.16, Age_Group='50s')
# Pandas(Index=261, age=20, sex='female', bmi=26.84, children=1, smoker='yes', region='southeast', charges=17085.2676, Age_Group='20s')
# Pandas(Index=262, age=52, sex='male', bmi=24.32, children=3, smoker='yes', region='northeast', charges=24869.8368, Age_Group='50s')
# Pandas(Index=263, age=19, sex='male', bmi=36.955, children=0, smoker='yes', region='northwest', charges=36219.40545, Age_Group='Teens')
# Pandas(Index=264, age=53, sex='female', bmi=38.06, children=3, smoker='no', region='southeast', charges=20462.99766, Age_Group='50s')
# Pandas(Index=265, age=46, sex='male', bmi=42.35, children=3, smoker='yes', region='southeast', charges=46151.1245, Age_Group='40s')
# Pandas(Index=266, age=40, sex='male', bmi=19.8, children=1, smoker='yes', region='southeast', charges=17179.522, Age_Group='40s')
# Pandas(Index=267, age=59, sex='female', bmi=32.395, children=3, smoker='no', region='northeast', charges=14590.63205, Age_Group='50s')
# Pandas(Index=268, age=45, sex='male', bmi=30.2, children=1, smoker='no', region='southwest', charges=7441.053, Age_Group='40s')
# Pandas(Index=269, age=49, sex='male', bmi=25.84, children=1, smoker='no', region='northeast', charges=9282.4806, Age_Group='40s')
# Pandas(Index=270, age=18, sex='male', bmi=29.37, children=1, smoker='no', region='southeast', charges=1719.4363, Age_Group='Teens')
# Pandas(Index=271, age=50, sex='male', bmi=34.2, children=2, smoker='yes', region='southwest', charges=42856.838, Age_Group='50s')
# Pandas(Index=272, age=41, sex='male', bmi=37.05, children=2, smoker='no', region='northwest', charges=7265.7025, Age_Group='40s')
# Pandas(Index=273, age=50, sex='male', bmi=27.455, children=1, smoker='no', region='northeast', charges=9617.66245, Age_Group='50s')
# Pandas(Index=274, age=25, sex='male', bmi=27.55, children=0, smoker='no', region='northwest', charges=2523.1695, Age_Group='20s')
# Pandas(Index=275, age=47, sex='female', bmi=26.6, children=2, smoker='no', region='northeast', charges=9715.841, Age_Group='40s')
# Pandas(Index=276, age=19, sex='male', bmi=20.615, children=2, smoker='no', region='northwest', charges=2803.69785, Age_Group='Teens')
# Pandas(Index=277, age=22, sex='female', bmi=24.3, children=0, smoker='no', region='southwest', charges=2150.469, Age_Group='20s')
# Pandas(Index=278, age=59, sex='male', bmi=31.79, children=2, smoker='no', region='southeast', charges=12928.7911, Age_Group='50s')
# Pandas(Index=279, age=51, sex='female', bmi=21.56, children=1, smoker='no', region='southeast', charges=9855.1314, Age_Group='50s')
# Pandas(Index=280, age=40, sex='female', bmi=28.12, children=1, smoker='yes', region='northeast', charges=22331.5668, Age_Group='40s')
# Pandas(Index=281, age=54, sex='male', bmi=40.565, children=3, smoker='yes', region='northeast', charges=48549.17835, Age_Group='50s')
# Pandas(Index=282, age=30, sex='male', bmi=27.645, children=1, smoker='no', region='northeast', charges=4237.12655, Age_Group='30s')
# Pandas(Index=283, age=55, sex='female', bmi=32.395, children=1, smoker='no', region='northeast', charges=11879.10405, Age_Group='50s')
# Pandas(Index=284, age=52, sex='female', bmi=31.2, children=0, smoker='no', region='southwest', charges=9625.92, Age_Group='50s')
# Pandas(Index=285, age=46, sex='male', bmi=26.62, children=1, smoker='no', region='southeast', charges=7742.1098, Age_Group='40s')
# Pandas(Index=286, age=46, sex='female', bmi=48.07, children=2, smoker='no', region='northeast', charges=9432.9253, Age_Group='40s')
# Pandas(Index=287, age=63, sex='female', bmi=26.22, children=0, smoker='no', region='northwest', charges=14256.1928, Age_Group='60s')
# Pandas(Index=288, age=59, sex='female', bmi=36.765, children=1, smoker='yes', region='northeast', charges=47896.79135, Age_Group='50s')
# Pandas(Index=289, age=52, sex='male', bmi=26.4, children=3, smoker='no', region='southeast', charges=25992.82104, Age_Group='50s')
# Pandas(Index=290, age=28, sex='female', bmi=33.4, children=0, smoker='no', region='southwest', charges=3172.018, Age_Group='20s')
# Pandas(Index=291, age=29, sex='male', bmi=29.64, children=1, smoker='no', region='northeast', charges=20277.80751, Age_Group='20s')
# Pandas(Index=292, age=25, sex='male', bmi=45.54, children=2, smoker='yes', region='southeast', charges=42112.2356, Age_Group='20s')
# Pandas(Index=293, age=22, sex='female', bmi=28.82, children=0, smoker='no', region='southeast', charges=2156.7518, Age_Group='20s')
# Pandas(Index=294, age=25, sex='male', bmi=26.8, children=3, smoker='no', region='southwest', charges=3906.127, Age_Group='20s')
# Pandas(Index=295, age=18, sex='male', bmi=22.99, children=0, smoker='no', region='northeast', charges=1704.5681, Age_Group='Teens')
# Pandas(Index=296, age=19, sex='male', bmi=27.7, children=0, smoker='yes', region='southwest', charges=16297.846, Age_Group='Teens')
# Pandas(Index=297, age=47, sex='male', bmi=25.41, children=1, smoker='yes', region='southeast', charges=21978.6769, Age_Group='40s')
# Pandas(Index=298, age=31, sex='male', bmi=34.39, children=3, smoker='yes', region='northwest', charges=38746.3551, Age_Group='30s')
# Pandas(Index=299, age=48, sex='female', bmi=28.88, children=1, smoker='no', region='northwest', charges=9249.4952, Age_Group='40s')
# Pandas(Index=300, age=36, sex='male', bmi=27.55, children=3, smoker='no', region='northeast', charges=6746.7425, Age_Group='30s')
# Pandas(Index=301, age=53, sex='female', bmi=22.61, children=3, smoker='yes', region='northeast', charges=24873.3849, Age_Group='50s')
# Pandas(Index=302, age=56, sex='female', bmi=37.51, children=2, smoker='no', region='southeast', charges=12265.5069, Age_Group='50s')
# Pandas(Index=303, age=28, sex='female', bmi=33.0, children=2, smoker='no', region='southeast', charges=4349.462, Age_Group='20s')
# Pandas(Index=304, age=57, sex='female', bmi=38.0, children=2, smoker='no', region='southwest', charges=12646.207, Age_Group='50s')
# Pandas(Index=305, age=29, sex='male', bmi=33.345, children=2, smoker='no', region='northwest', charges=19442.3535, Age_Group='20s')
# Pandas(Index=306, age=28, sex='female', bmi=27.5, children=2, smoker='no', region='southwest', charges=20177.67113, Age_Group='20s')
# Pandas(Index=307, age=30, sex='female', bmi=33.33, children=1, smoker='no', region='southeast', charges=4151.0287, Age_Group='30s')
# Pandas(Index=308, age=58, sex='male', bmi=34.865, children=0, smoker='no', region='northeast', charges=11944.59435, Age_Group='50s')
# Pandas(Index=309, age=41, sex='female', bmi=33.06, children=2, smoker='no', region='northwest', charges=7749.1564, Age_Group='40s')
# Pandas(Index=310, age=50, sex='male', bmi=26.6, children=0, smoker='no', region='southwest', charges=8444.474, Age_Group='50s')
# Pandas(Index=311, age=19, sex='female', bmi=24.7, children=0, smoker='no', region='southwest', charges=1737.376, Age_Group='Teens')
# Pandas(Index=312, age=43, sex='male', bmi=35.97, children=3, smoker='yes', region='southeast', charges=42124.5153, Age_Group='40s')
# Pandas(Index=313, age=49, sex='male', bmi=35.86, children=0, smoker='no', region='southeast', charges=8124.4084, Age_Group='40s')
# Pandas(Index=314, age=27, sex='female', bmi=31.4, children=0, smoker='yes', region='southwest', charges=34838.873, Age_Group='20s')
# Pandas(Index=315, age=52, sex='male', bmi=33.25, children=0, smoker='no', region='northeast', charges=9722.7695, Age_Group='50s')
# Pandas(Index=316, age=50, sex='male', bmi=32.205, children=0, smoker='no', region='northwest', charges=8835.26495, Age_Group='50s')
# Pandas(Index=317, age=54, sex='male', bmi=32.775, children=0, smoker='no', region='northeast', charges=10435.06525, Age_Group='50s')
# Pandas(Index=318, age=44, sex='female', bmi=27.645, children=0, smoker='no', region='northwest', charges=7421.19455, Age_Group='40s')
# Pandas(Index=319, age=32, sex='male', bmi=37.335, children=1, smoker='no', region='northeast', charges=4667.60765, Age_Group='30s')
# Pandas(Index=320, age=34, sex='male', bmi=25.27, children=1, smoker='no', region='northwest', charges=4894.7533, Age_Group='30s')
# Pandas(Index=321, age=26, sex='female', bmi=29.64, children=4, smoker='no', region='northeast', charges=24671.66334, Age_Group='20s')
# Pandas(Index=322, age=34, sex='male', bmi=30.8, children=0, smoker='yes', region='southwest', charges=35491.64, Age_Group='30s')
# Pandas(Index=323, age=57, sex='male', bmi=40.945, children=0, smoker='no', region='northeast', charges=11566.30055, Age_Group='50s')
# Pandas(Index=324, age=29, sex='male', bmi=27.2, children=0, smoker='no', region='southwest', charges=2866.091, Age_Group='20s')
# Pandas(Index=325, age=40, sex='male', bmi=34.105, children=1, smoker='no', region='northeast', charges=6600.20595, Age_Group='40s')
# Pandas(Index=326, age=27, sex='female', bmi=23.21, children=1, smoker='no', region='southeast', charges=3561.8889, Age_Group='20s')
# Pandas(Index=327, age=45, sex='male', bmi=36.48, children=2, smoker='yes', region='northwest', charges=42760.5022, Age_Group='40s')
# Pandas(Index=328, age=64, sex='female', bmi=33.8, children=1, smoker='yes', region='southwest', charges=47928.03, Age_Group='60s')
# Pandas(Index=329, age=52, sex='male', bmi=36.7, children=0, smoker='no', region='southwest', charges=9144.565, Age_Group='50s')
# Pandas(Index=330, age=61, sex='female', bmi=36.385, children=1, smoker='yes', region='northeast', charges=48517.56315, Age_Group='60s')
# Pandas(Index=331, age=52, sex='male', bmi=27.36, children=0, smoker='yes', region='northwest', charges=24393.6224, Age_Group='50s')
# Pandas(Index=332, age=61, sex='female', bmi=31.16, children=0, smoker='no', region='northwest', charges=13429.0354, Age_Group='60s')
# Pandas(Index=333, age=56, sex='female', bmi=28.785, children=0, smoker='no', region='northeast', charges=11658.37915, Age_Group='50s')
# Pandas(Index=334, age=43, sex='female', bmi=35.72, children=2, smoker='no', region='northeast', charges=19144.57652, Age_Group='40s')
# Pandas(Index=335, age=64, sex='male', bmi=34.5, children=0, smoker='no', region='southwest', charges=13822.803, Age_Group='60s')
# Pandas(Index=336, age=60, sex='male', bmi=25.74, children=0, smoker='no', region='southeast', charges=12142.5786, Age_Group='60s')
# Pandas(Index=337, age=62, sex='male', bmi=27.55, children=1, smoker='no', region='northwest', charges=13937.6665, Age_Group='60s')
# Pandas(Index=338, age=50, sex='male', bmi=32.3, children=1, smoker='yes', region='northeast', charges=41919.097, Age_Group='50s')
# Pandas(Index=339, age=46, sex='female', bmi=27.72, children=1, smoker='no', region='southeast', charges=8232.6388, Age_Group='40s')
# Pandas(Index=340, age=24, sex='female', bmi=27.6, children=0, smoker='no', region='southwest', charges=18955.22017, Age_Group='20s')
# Pandas(Index=341, age=62, sex='male', bmi=30.02, children=0, smoker='no', region='northwest', charges=13352.0998, Age_Group='60s')
# Pandas(Index=342, age=60, sex='female', bmi=27.55, children=0, smoker='no', region='northeast', charges=13217.0945, Age_Group='60s')
# Pandas(Index=343, age=63, sex='male', bmi=36.765, children=0, smoker='no', region='northeast', charges=13981.85035, Age_Group='60s')
# Pandas(Index=344, age=49, sex='female', bmi=41.47, children=4, smoker='no', region='southeast', charges=10977.2063, Age_Group='40s')
# Pandas(Index=345, age=34, sex='female', bmi=29.26, children=3, smoker='no', region='southeast', charges=6184.2994, Age_Group='30s')
# Pandas(Index=346, age=33, sex='male', bmi=35.75, children=2, smoker='no', region='southeast', charges=4889.9995, Age_Group='30s')
# Pandas(Index=347, age=46, sex='male', bmi=33.345, children=1, smoker='no', region='northeast', charges=8334.45755, Age_Group='40s')
# Pandas(Index=348, age=36, sex='female', bmi=29.92, children=1, smoker='no', region='southeast', charges=5478.0368, Age_Group='30s')
# Pandas(Index=349, age=19, sex='male', bmi=27.835, children=0, smoker='no', region='northwest', charges=1635.73365, Age_Group='Teens')
# Pandas(Index=350, age=57, sex='female', bmi=23.18, children=0, smoker='no', region='northwest', charges=11830.6072, Age_Group='50s')
# Pandas(Index=351, age=50, sex='female', bmi=25.6, children=0, smoker='no', region='southwest', charges=8932.084, Age_Group='50s')
# Pandas(Index=352, age=30, sex='female', bmi=27.7, children=0, smoker='no', region='southwest', charges=3554.203, Age_Group='30s')
# Pandas(Index=353, age=33, sex='male', bmi=35.245, children=0, smoker='no', region='northeast', charges=12404.8791, Age_Group='30s')
# Pandas(Index=354, age=18, sex='female', bmi=38.28, children=0, smoker='no', region='southeast', charges=14133.03775, Age_Group='Teens')
# Pandas(Index=355, age=46, sex='male', bmi=27.6, children=0, smoker='no', region='southwest', charges=24603.04837, Age_Group='40s')
# Pandas(Index=356, age=46, sex='male', bmi=43.89, children=3, smoker='no', region='southeast', charges=8944.1151, Age_Group='40s')
# Pandas(Index=357, age=47, sex='male', bmi=29.83, children=3, smoker='no', region='northwest', charges=9620.3307, Age_Group='40s')
# Pandas(Index=358, age=23, sex='male', bmi=41.91, children=0, smoker='no', region='southeast', charges=1837.2819, Age_Group='20s')
# Pandas(Index=359, age=18, sex='female', bmi=20.79, children=0, smoker='no', region='southeast', charges=1607.5101, Age_Group='Teens')
# Pandas(Index=360, age=48, sex='female', bmi=32.3, children=2, smoker='no', region='northeast', charges=10043.249, Age_Group='40s')
# Pandas(Index=361, age=35, sex='male', bmi=30.5, children=1, smoker='no', region='southwest', charges=4751.07, Age_Group='30s')
# Pandas(Index=362, age=19, sex='female', bmi=21.7, children=0, smoker='yes', region='southwest', charges=13844.506, Age_Group='Teens')
# Pandas(Index=363, age=21, sex='female', bmi=26.4, children=1, smoker='no', region='southwest', charges=2597.779, Age_Group='20s')
# Pandas(Index=364, age=21, sex='female', bmi=21.89, children=2, smoker='no', region='southeast', charges=3180.5101, Age_Group='20s')
# ...
# Pandas(Index=1218, age=46, sex='female', bmi=34.6, children=1, smoker='yes', region='southwest', charges=41661.602, Age_Group='40s')
# Pandas(Index=1219, age=38, sex='female', bmi=30.21, children=3, smoker='no', region='northwest', charges=7537.1639, Age_Group='30s')
# Pandas(Index=1220, age=30, sex='female', bmi=21.945, children=1, smoker='no', region='northeast', charges=4718.20355, Age_Group='30s')
# Pandas(Index=1221, age=40, sex='male', bmi=24.97, children=2, smoker='no', region='southeast', charges=6593.5083, Age_Group='40s')
# Pandas(Index=1222, age=50, sex='male', bmi=25.3, children=0, smoker='no', region='southeast', charges=8442.667, Age_Group='50s')
# Pandas(Index=1223, age=20, sex='female', bmi=24.42, children=0, smoker='yes', region='southeast', charges=26125.67477, Age_Group='20s')
# Pandas(Index=1224, age=41, sex='male', bmi=23.94, children=1, smoker='no', region='northeast', charges=6858.4796, Age_Group='40s')
# Pandas(Index=1225, age=33, sex='female', bmi=39.82, children=1, smoker='no', region='southeast', charges=4795.6568, Age_Group='30s')
# Pandas(Index=1226, age=38, sex='male', bmi=16.815, children=2, smoker='no', region='northeast', charges=6640.54485, Age_Group='30s')
# Pandas(Index=1227, age=42, sex='male', bmi=37.18, children=2, smoker='no', region='southeast', charges=7162.0122, Age_Group='40s')
# Pandas(Index=1228, age=56, sex='male', bmi=34.43, children=0, smoker='no', region='southeast', charges=10594.2257, Age_Group='50s')
# Pandas(Index=1229, age=58, sex='male', bmi=30.305, children=0, smoker='no', region='northeast', charges=11938.25595, Age_Group='50s')
# Pandas(Index=1230, age=52, sex='male', bmi=34.485, children=3, smoker='yes', region='northwest', charges=60021.39897, Age_Group='50s')
# Pandas(Index=1231, age=20, sex='female', bmi=21.8, children=0, smoker='yes', region='southwest', charges=20167.33603, Age_Group='20s')
# Pandas(Index=1232, age=54, sex='female', bmi=24.605, children=3, smoker='no', region='northwest', charges=12479.70895, Age_Group='50s')
# Pandas(Index=1233, age=58, sex='male', bmi=23.3, children=0, smoker='no', region='southwest', charges=11345.519, Age_Group='50s')
# Pandas(Index=1234, age=45, sex='female', bmi=27.83, children=2, smoker='no', region='southeast', charges=8515.7587, Age_Group='40s')
# Pandas(Index=1235, age=26, sex='male', bmi=31.065, children=0, smoker='no', region='northwest', charges=2699.56835, Age_Group='20s')
# Pandas(Index=1236, age=63, sex='female', bmi=21.66, children=0, smoker='no', region='northeast', charges=14449.8544, Age_Group='60s')
# Pandas(Index=1237, age=58, sex='female', bmi=28.215, children=0, smoker='no', region='northwest', charges=12224.35085, Age_Group='50s')
# Pandas(Index=1238, age=37, sex='male', bmi=22.705, children=3, smoker='no', region='northeast', charges=6985.50695, Age_Group='30s')
# Pandas(Index=1239, age=25, sex='female', bmi=42.13, children=1, smoker='no', region='southeast', charges=3238.4357, Age_Group='20s')
# Pandas(Index=1240, age=52, sex='male', bmi=41.8, children=2, smoker='yes', region='southeast', charges=47269.854, Age_Group='50s')
# Pandas(Index=1241, age=64, sex='male', bmi=36.96, children=2, smoker='yes', region='southeast', charges=49577.6624, Age_Group='60s')
# Pandas(Index=1242, age=22, sex='female', bmi=21.28, children=3, smoker='no', region='northwest', charges=4296.2712, Age_Group='20s')
# Pandas(Index=1243, age=28, sex='female', bmi=33.11, children=0, smoker='no', region='southeast', charges=3171.6149, Age_Group='20s')
# Pandas(Index=1244, age=18, sex='male', bmi=33.33, children=0, smoker='no', region='southeast', charges=1135.9407, Age_Group='Teens')
# Pandas(Index=1245, age=28, sex='male', bmi=24.3, children=5, smoker='no', region='southwest', charges=5615.369, Age_Group='20s')
# Pandas(Index=1246, age=45, sex='female', bmi=25.7, children=3, smoker='no', region='southwest', charges=9101.798, Age_Group='40s')
# Pandas(Index=1247, age=33, sex='male', bmi=29.4, children=4, smoker='no', region='southwest', charges=6059.173, Age_Group='30s')
# Pandas(Index=1248, age=18, sex='female', bmi=39.82, children=0, smoker='no', region='southeast', charges=1633.9618, Age_Group='Teens')
# Pandas(Index=1249, age=32, sex='male', bmi=33.63, children=1, smoker='yes', region='northeast', charges=37607.5277, Age_Group='30s')
# Pandas(Index=1250, age=24, sex='male', bmi=29.83, children=0, smoker='yes', region='northeast', charges=18648.4217, Age_Group='20s')
# Pandas(Index=1251, age=19, sex='male', bmi=19.8, children=0, smoker='no', region='southwest', charges=1241.565, Age_Group='Teens')
# Pandas(Index=1252, age=20, sex='male', bmi=27.3, children=0, smoker='yes', region='southwest', charges=16232.847, Age_Group='20s')
# Pandas(Index=1253, age=40, sex='female', bmi=29.3, children=4, smoker='no', region='southwest', charges=15828.82173, Age_Group='40s')
# Pandas(Index=1254, age=34, sex='female', bmi=27.72, children=0, smoker='no', region='southeast', charges=4415.1588, Age_Group='30s')
# Pandas(Index=1255, age=42, sex='female', bmi=37.9, children=0, smoker='no', region='southwest', charges=6474.013, Age_Group='40s')
# Pandas(Index=1256, age=51, sex='female', bmi=36.385, children=3, smoker='no', region='northwest', charges=11436.73815, Age_Group='50s')
# Pandas(Index=1257, age=54, sex='female', bmi=27.645, children=1, smoker='no', region='northwest', charges=11305.93455, Age_Group='50s')
# Pandas(Index=1258, age=55, sex='male', bmi=37.715, children=3, smoker='no', region='northwest', charges=30063.58055, Age_Group='50s')
# Pandas(Index=1259, age=52, sex='female', bmi=23.18, children=0, smoker='no', region='northeast', charges=10197.7722, Age_Group='50s')
# Pandas(Index=1260, age=32, sex='female', bmi=20.52, children=0, smoker='no', region='northeast', charges=4544.2348, Age_Group='30s')
# Pandas(Index=1261, age=28, sex='male', bmi=37.1, children=1, smoker='no', region='southwest', charges=3277.161, Age_Group='20s')
# Pandas(Index=1262, age=41, sex='female', bmi=28.05, children=1, smoker='no', region='southeast', charges=6770.1925, Age_Group='40s')
# Pandas(Index=1263, age=43, sex='female', bmi=29.9, children=1, smoker='no', region='southwest', charges=7337.748, Age_Group='40s')
# Pandas(Index=1264, age=49, sex='female', bmi=33.345, children=2, smoker='no', region='northeast', charges=10370.91255, Age_Group='40s')
# Pandas(Index=1265, age=64, sex='male', bmi=23.76, children=0, smoker='yes', region='southeast', charges=26926.5144, Age_Group='60s')
# Pandas(Index=1266, age=55, sex='female', bmi=30.5, children=0, smoker='no', region='southwest', charges=10704.47, Age_Group='50s')
# Pandas(Index=1267, age=24, sex='male', bmi=31.065, children=0, smoker='yes', region='northeast', charges=34254.05335, Age_Group='20s')
# Pandas(Index=1268, age=20, sex='female', bmi=33.3, children=0, smoker='no', region='southwest', charges=1880.487, Age_Group='20s')
# Pandas(Index=1269, age=45, sex='male', bmi=27.5, children=3, smoker='no', region='southwest', charges=8615.3, Age_Group='40s')
# Pandas(Index=1270, age=26, sex='male', bmi=33.915, children=1, smoker='no', region='northwest', charges=3292.52985, Age_Group='20s')
# Pandas(Index=1271, age=25, sex='female', bmi=34.485, children=0, smoker='no', region='northwest', charges=3021.80915, Age_Group='20s')
# Pandas(Index=1272, age=43, sex='male', bmi=25.52, children=5, smoker='no', region='southeast', charges=14478.33015, Age_Group='40s')
# Pandas(Index=1273, age=35, sex='male', bmi=27.61, children=1, smoker='no', region='southeast', charges=4747.0529, Age_Group='30s')
# Pandas(Index=1274, age=26, sex='male', bmi=27.06, children=0, smoker='yes', region='southeast', charges=17043.3414, Age_Group='20s')
# Pandas(Index=1275, age=57, sex='male', bmi=23.7, children=0, smoker='no', region='southwest', charges=10959.33, Age_Group='50s')
# Pandas(Index=1276, age=22, sex='female', bmi=30.4, children=0, smoker='no', region='northeast', charges=2741.948, Age_Group='20s')
# Pandas(Index=1277, age=32, sex='female', bmi=29.735, children=0, smoker='no', region='northwest', charges=4357.04365, Age_Group='30s')
# Pandas(Index=1278, age=39, sex='male', bmi=29.925, children=1, smoker='yes', region='northeast', charges=22462.04375, Age_Group='30s')
# Pandas(Index=1279, age=25, sex='female', bmi=26.79, children=2, smoker='no', region='northwest', charges=4189.1131, Age_Group='20s')
# Pandas(Index=1280, age=48, sex='female', bmi=33.33, children=0, smoker='no', region='southeast', charges=8283.6807, Age_Group='40s')
# Pandas(Index=1281, age=47, sex='female', bmi=27.645, children=2, smoker='yes', region='northwest', charges=24535.69855, Age_Group='40s')
# Pandas(Index=1282, age=18, sex='female', bmi=21.66, children=0, smoker='yes', region='northeast', charges=14283.4594, Age_Group='Teens')
# Pandas(Index=1283, age=18, sex='male', bmi=30.03, children=1, smoker='no', region='southeast', charges=1720.3537, Age_Group='Teens')
# Pandas(Index=1284, age=61, sex='male', bmi=36.3, children=1, smoker='yes', region='southwest', charges=47403.88, Age_Group='60s')
# Pandas(Index=1285, age=47, sex='female', bmi=24.32, children=0, smoker='no', region='northeast', charges=8534.6718, Age_Group='40s')
# Pandas(Index=1286, age=28, sex='female', bmi=17.29, children=0, smoker='no', region='northeast', charges=3732.6251, Age_Group='20s')
# Pandas(Index=1287, age=36, sex='female', bmi=25.9, children=1, smoker='no', region='southwest', charges=5472.449, Age_Group='30s')
# Pandas(Index=1288, age=20, sex='male', bmi=39.4, children=2, smoker='yes', region='southwest', charges=38344.566, Age_Group='20s')
# Pandas(Index=1289, age=44, sex='male', bmi=34.32, children=1, smoker='no', region='southeast', charges=7147.4728, Age_Group='40s')
# Pandas(Index=1290, age=38, sex='female', bmi=19.95, children=2, smoker='no', region='northeast', charges=7133.9025, Age_Group='30s')
# Pandas(Index=1291, age=19, sex='male', bmi=34.9, children=0, smoker='yes', region='southwest', charges=34828.654, Age_Group='Teens')
# Pandas(Index=1292, age=21, sex='male', bmi=23.21, children=0, smoker='no', region='southeast', charges=1515.3449, Age_Group='20s')
# Pandas(Index=1293, age=46, sex='male', bmi=25.745, children=3, smoker='no', region='northwest', charges=9301.89355, Age_Group='40s')
# Pandas(Index=1294, age=58, sex='male', bmi=25.175, children=0, smoker='no', region='northeast', charges=11931.12525, Age_Group='50s')
# Pandas(Index=1295, age=20, sex='male', bmi=22.0, children=1, smoker='no', region='southwest', charges=1964.78, Age_Group='20s')
# Pandas(Index=1296, age=18, sex='male', bmi=26.125, children=0, smoker='no', region='northeast', charges=1708.92575, Age_Group='Teens')
# Pandas(Index=1297, age=28, sex='female', bmi=26.51, children=2, smoker='no', region='southeast', charges=4340.4409, Age_Group='20s')
# Pandas(Index=1298, age=33, sex='male', bmi=27.455, children=2, smoker='no', region='northwest', charges=5261.46945, Age_Group='30s')
# Pandas(Index=1299, age=19, sex='female', bmi=25.745, children=1, smoker='no', region='northwest', charges=2710.82855, Age_Group='Teens')
# Pandas(Index=1300, age=45, sex='male', bmi=30.36, children=0, smoker='yes', region='southeast', charges=62592.87309, Age_Group='40s')
# Pandas(Index=1301, age=62, sex='male', bmi=30.875, children=3, smoker='yes', region='northwest', charges=46718.16325, Age_Group='60s')
# Pandas(Index=1302, age=25, sex='female', bmi=20.8, children=1, smoker='no', region='southwest', charges=3208.787, Age_Group='20s')
# Pandas(Index=1303, age=43, sex='male', bmi=27.8, children=0, smoker='yes', region='southwest', charges=37829.7242, Age_Group='40s')
# Pandas(Index=1304, age=42, sex='male', bmi=24.605, children=2, smoker='yes', region='northeast', charges=21259.37795, Age_Group='40s')
# Pandas(Index=1305, age=24, sex='female', bmi=27.72, children=0, smoker='no', region='southeast', charges=2464.6188, Age_Group='20s')
# Pandas(Index=1306, age=29, sex='female', bmi=21.85, children=0, smoker='yes', region='northeast', charges=16115.3045, Age_Group='20s')
# Pandas(Index=1307, age=32, sex='male', bmi=28.12, children=4, smoker='yes', region='northwest', charges=21472.4788, Age_Group='30s')
# Pandas(Index=1308, age=25, sex='female', bmi=30.2, children=0, smoker='yes', region='southwest', charges=33900.653, Age_Group='20s')
# Pandas(Index=1309, age=41, sex='male', bmi=32.2, children=2, smoker='no', region='southwest', charges=6875.961, Age_Group='40s')
# Pandas(Index=1310, age=42, sex='male', bmi=26.315, children=1, smoker='no', region='northwest', charges=6940.90985, Age_Group='40s')
# Pandas(Index=1311, age=33, sex='female', bmi=26.695, children=0, smoker='no', region='northwest', charges=4571.41305, Age_Group='30s')
# Pandas(Index=1312, age=34, sex='male', bmi=42.9, children=1, smoker='no', region='southwest', charges=4536.259, Age_Group='30s')
# Pandas(Index=1313, age=19, sex='female', bmi=34.7, children=2, smoker='yes', region='southwest', charges=36397.576, Age_Group='Teens')
# Pandas(Index=1314, age=30, sex='female', bmi=23.655, children=3, smoker='yes', region='northwest', charges=18765.87545, Age_Group='30s')
# Pandas(Index=1315, age=18, sex='male', bmi=28.31, children=1, smoker='no', region='northeast', charges=11272.33139, Age_Group='Teens')
# Pandas(Index=1316, age=19, sex='female', bmi=20.6, children=0, smoker='no', region='southwest', charges=1731.677, Age_Group='Teens')
# Pandas(Index=1317, age=18, sex='male', bmi=53.13, children=0, smoker='no', region='southeast', charges=1163.4627, Age_Group='Teens')
# Pandas(Index=1318, age=35, sex='male', bmi=39.71, children=4, smoker='no', region='northeast', charges=19496.71917, Age_Group='30s')
# Pandas(Index=1319, age=39, sex='female', bmi=26.315, children=2, smoker='no', region='northwest', charges=7201.70085, Age_Group='30s')
# Pandas(Index=1320, age=31, sex='male', bmi=31.065, children=3, smoker='no', region='northwest', charges=5425.02335, Age_Group='30s')
# Pandas(Index=1321, age=62, sex='male', bmi=26.695, children=0, smoker='yes', region='northeast', charges=28101.33305, Age_Group='60s')
# Pandas(Index=1322, age=62, sex='male', bmi=38.83, children=0, smoker='no', region='southeast', charges=12981.3457, Age_Group='60s')
# Pandas(Index=1323, age=42, sex='female', bmi=40.37, children=2, smoker='yes', region='southeast', charges=43896.3763, Age_Group='40s')
# Pandas(Index=1324, age=31, sex='male', bmi=25.935, children=1, smoker='no', region='northwest', charges=4239.89265, Age_Group='30s')
# Pandas(Index=1325, age=61, sex='male', bmi=33.535, children=0, smoker='no', region='northeast', charges=13143.33665, Age_Group='60s')
# Pandas(Index=1326, age=42, sex='female', bmi=32.87, children=0, smoker='no', region='northeast', charges=7050.0213, Age_Group='40s')
# Pandas(Index=1327, age=51, sex='male', bmi=30.03, children=1, smoker='no', region='southeast', charges=9377.9047, Age_Group='50s')
# Pandas(Index=1328, age=23, sex='female', bmi=24.225, children=2, smoker='no', region='northeast', charges=22395.74424, Age_Group='20s')
# Pandas(Index=1329, age=52, sex='male', bmi=38.6, children=2, smoker='no', region='southwest', charges=10325.206, Age_Group='50s')
# Pandas(Index=1330, age=57, sex='female', bmi=25.74, children=2, smoker='no', region='southeast', charges=12629.1656, Age_Group='50s')
# Pandas(Index=1331, age=23, sex='female', bmi=33.4, children=0, smoker='no', region='southwest', charges=10795.93733, Age_Group='20s')
# Pandas(Index=1332, age=52, sex='female', bmi=44.7, children=3, smoker='no', region='southwest', charges=11411.685, Age_Group='50s')
# Pandas(Index=1333, age=50, sex='male', bmi=30.97, children=3, smoker='no', region='northwest', charges=10600.5483, Age_Group='50s')
# Pandas(Index=1334, age=18, sex='female', bmi=31.92, children=0, smoker='no', region='northeast', charges=2205.9808, Age_Group='Teens')
# Pandas(Index=1335, age=18, sex='female', bmi=36.85, children=0, smoker='no', region='southeast', charges=1629.8335, Age_Group='Teens')
# Pandas(Index=1336, age=21, sex='female', bmi=25.8, children=0, smoker='no', region='southwest', charges=2007.945, Age_Group='20s')
# Pandas(Index=1337, age=61, sex='female', bmi=29.07, children=0, smoker='yes', region='northwest', charges=29141.3603, Age_Group='60s')

# %%
for row in df.itertuples():
  if row.age < 20:
    df.at[row.Index, 'Age_Group'] = "Teens"
  elif row.age < 30:
    df.at[row.Index, 'Age_Group'] = "20s"
  elif row.age < 40:
    df.at[row.Index, 'Age_Group'] = "30s"
  elif row.age < 50:
    df.at[row.Index, 'Age_Group'] = "40s"
  elif row.age < 60:
    df.at[row.Index, 'Age_Group'] = "50s"
  else:
    df.at[row.Index, 'Age_Group'] = "60s"

df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges Age_Group
# 0   19  female  27.900         0    yes  southwest  16884.92400     Teens
# 1   18    male  33.770         1     no  southeast   1725.55230     Teens
# 2   28    male  33.000         3     no  southeast   4449.46200       20s
# 3   33    male  22.705         0     no  northwest  21984.47061       30s
# 4   32    male  28.880         0     no  northwest   3866.85520       30s

# %% [markdown]
# # **You Try: Bin Region with Itertuples**

# %% [markdown]
# Bin the regions into a new column called 'region_group'. If the region is southwest or southeast, label it as 'south'. If the region is northwest or northeast, label it as 'north'. Use itertuples().

# %%
for row in df.itertuples():
  if ((row.region == 'southwest') | (row.region =='southeast')):
    df.at[row.Index, 'region_group'] = "south"
  elif ((row.region == 'northwest') | (row.region =='northeast')):
    df.at[row.Index, 'region_group'] = "north"

df
# Out:
#       age     sex     bmi  children smoker     region      charges Age_Group  \
# 0      19  female  27.900         0    yes  southwest  16884.92400     Teens
# 1      18    male  33.770         1     no  southeast   1725.55230     Teens
# 2      28    male  33.000         3     no  southeast   4449.46200       20s
# 3      33    male  22.705         0     no  northwest  21984.47061       30s
# 4      32    male  28.880         0     no  northwest   3866.85520       30s
# ...   ...     ...     ...       ...    ...        ...          ...       ...
# 1333   50    male  30.970         3     no  northwest  10600.54830       50s
# 1334   18  female  31.920         0     no  northeast   2205.98080     Teens
# 1335   18  female  36.850         0     no  southeast   1629.83350     Teens
# 1336   21  female  25.800         0     no  southwest   2007.94500       20s
# 1337   61  female  29.070         0    yes  northwest  29141.36030       60s
#
#      region_group
# 0           south
# 1           south
# 2           south
# 3           north
# 4           north
# ...           ...
# 1333        north
# 1334        north
# 1335        south
# 1336        south
# 1337        north
#
# [1338 rows x 9 columns]

# %% [markdown]
# # **Merge**

# %% [markdown]
# weather_df is a dataframe with a very generalized weather statement for each region.

# %%
weather_df = pd.DataFrame({'Region':['southwest', 'northwest', 'southeast', 'northeast'],
                      'weather':['Dry Heat', 'Wet', 'Humid Heat', 'Snow']})
weather_df
# Out:
#       Region     weather
# 0  southwest    Dry Heat
# 1  northwest         Wet
# 2  southeast  Humid Heat
# 3  northeast        Snow

# %% [markdown]
# Merge the df dataframe with the weather_df dataframe on the region column from the df dataframe and the Region column from the weather_df dataframe. Merge so that all the records of the df are returned and the matching records from the weather_df are returned (https://www.w3schools.com/sql/sql_join.asp)

# %%
merged_df = pd.merge(df, weather_df, how='left', left_on='region', right_on='Region')
merged_df
# Out:
#       age  gender    bmi  children smoker     region     charges     Region  \
# 0      19  female  27.90       0.0    yes  southwest  16884.9240  southwest
# 1      18    male  33.77       1.0    NaN  southeast   1725.5523  southeast
# 2      28    male  33.00       0.0     no  southeast   4449.4620  southeast
# 3      32    male  28.88       0.0     no  northwest   3866.8552  northwest
# 4      31  female  25.74       0.0     no  southeast   3756.6216  southeast
# ...   ...     ...    ...       ...    ...        ...         ...        ...
# 1330   50    male  30.97       3.0     no  northwest  10600.5483  northwest
# 1331   18  female  31.92       0.0     no  northeast   2205.9808  northeast
# 1332   18  female  36.85       0.0     no  southeast   1629.8335  southeast
# 1333   21  female  25.80       0.0     no  southwest   2007.9450  southwest
# 1334   61  female  29.07       0.0    yes  northwest  29141.3603  northwest
#
#          weather
# 0       Dry Heat
# 1     Humid Heat
# 2     Humid Heat
# 3            Wet
# 4     Humid Heat
# ...          ...
# 1330         Wet
# 1331        Snow
# 1332  Humid Heat
# 1333    Dry Heat
# 1334         Wet
#
# [1335 rows x 9 columns]

# %% [markdown]
# # **Dates**

# %% [markdown]
# Here is a short dataframe of individuals that are participating in a study that keeps track of their heart rate. Format the signup-date to be a datetime string that follows the yyyy-mm-dd format.

# %%
import pandas as pd
df = pd.DataFrame({'age':[29, 55, 65, 18], 'gender':['male', 'female', 'male', 'female'], 'hr1':[98.1, 78, 65, 64], 'hr2':[110, 120, 129, 141], 'hr3':[76, 87, 77, 59], 'signup_date': ['02/14/2019', '01/05/2018', '05/23/2020', '12/10/2019'] }, index=['p1', 'p2', 'p3', 'p4'])
df.head()
# Out:
#     age  gender   hr1  hr2  hr3 signup_date
# p1   29    male  98.1  110   76  02/14/2019
# p2   55  female  78.0  120   87  01/05/2018
# p3   65    male  65.0  129   77  05/23/2020
# p4   18  female  64.0  141   59  12/10/2019

# %%
df.dtypes
# Out:
# age              int64
# gender          object
# hr1            float64
# hr2              int64
# hr3              int64
# signup_date     object
# dtype: object

# %% [markdown]
# Convert the signup_date to a datetime data type.

# %%
df['signup_date'] = pd.to_datetime(df['signup_date'])
df.dtypes
# Out:
# age                     int64
# gender                 object
# hr1                   float64
# hr2                     int64
# hr3                     int64
# signup_date    datetime64[ns]
# dtype: object

# %% [markdown]
# January 1st, 2023 is the end of the trial. Calculate how many days each participant is in the trial.

# %%
from datetime import datetime
EndOfTrialString = '2023-01-01'
EndOfTrial = datetime.strptime(EndOfTrialString, '%Y-%m-%d')

df['days_in_trial'] = (EndOfTrial - df['signup_date']).dt.days
df
# Out:
#     age  gender   hr1  hr2  hr3 signup_date  days_in_trial
# p1   29    male  98.1  110   76  2019-02-14           1417
# p2   55  female  78.0  120   87  2018-01-05           1822
# p3   65    male  65.0  129   77  2020-05-23            953
# p4   18  female  64.0  141   59  2019-12-10           1118

# %% [markdown]
# # **Practice - Dates and Merge**

# %%
import pandas as pd
holidayColors = pd.DataFrame({'Holiday':['Halloween', 'Christmas', 'Easter', 'Thanksgiving'], 'Color':['Orange and black', 'Red and green', 'Purple and Pink', 'Orange and Brown']})
holidayColors.head()
# Out:
#         Holiday             Color
# 0     Halloween  Orange and black
# 1     Christmas     Red and green
# 2        Easter   Purple and Pink
# 3  Thanksgiving  Orange and Brown

# %%
holidayDates = pd.DataFrame({'Holiday':['Halloween', 'Christmas', 'Easter', 'Thanksgiving', 'New Years Eve'], 'HolidayDate':['10/31/2023', '12/25/2023', '4/09/2023', '11/23/2023', '12/31/2023' ]})
holidayDates.head()
# Out:
#          Holiday HolidayDate
# 0      Halloween  10/31/2023
# 1      Christmas  12/25/2023
# 2         Easter   4/09/2023
# 3   Thanksgiving  11/23/2023
# 4  New Years Eve  12/31/2023

# %% [markdown]
# 1. Merge the holidayColors dataframe with the holidayDates dataframe on the Holiday column from the holidayColors dataframe and the holiday column from the holidayDates dataframe. Merge so that all the records of the holidayColors are returned and the matching records from the holidayDates are returned.

# %%
merged_df = pd.merge(holidayColors, holidayDates, how='left')
merged_df
# Out:
#         Holiday             Color HolidayDate
# 0     Halloween  Orange and black  10/31/2023
# 1     Christmas     Red and green  12/25/2023
# 2        Easter   Purple and Pink   4/09/2023
# 3  Thanksgiving  Orange and Brown  11/23/2023

# %% [markdown]
# 2. The first day of classes this semester was September 5th, 2023. Create a new column in the merged dataframe that is 'Days_away'. The column values will be the number of days away the holiday is from the start of the semester. Negative values indicate days that happened previously. For instance, since Easter happened in April, it will be negative days away.
#
# You will need to convert the HolidayDate column to a date type.

# %%
merged_df.dtypes
# Out:
# Holiday        object
# Color          object
# HolidayDate    object
# dtype: object

# %%
merged_df['HolidayDate'] = pd.to_datetime(merged_df.HolidayDate)
merged_df.dtypes
# Out:
# Holiday                object
# Color                  object
# HolidayDate    datetime64[ns]
# dtype: object

# %%
from datetime import datetime
StartofSemesterString = '2023-09-05'
StartofSemester = datetime.strptime(StartofSemesterString, '%Y-%m-%d')

merged_df['Days_away'] = (merged_df['HolidayDate'] - StartofSemester).dt.days
merged_df
# Out:
#         Holiday             Color HolidayDate  Days_away
# 0     Halloween  Orange and black  2023-10-31         56
# 1     Christmas     Red and green  2023-12-25        111
# 2        Easter   Purple and Pink  2023-04-09       -149
# 3  Thanksgiving  Orange and Brown  2023-11-23         79
